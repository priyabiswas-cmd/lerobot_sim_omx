# %%
from huggingface_hub import HfApi

api = HfApi()

api.create_repo(
    repo_id="Pidiya/sim-omx-pick-place",
    repo_type="dataset",
    exist_ok=True
)
# Out:
# RepoUrl('https://huggingface.co/datasets/Pidiya/sim-omx-pick-place', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Pidiya/sim-omx-pick-place')

# %%
from huggingface_hub import HfApi

api = HfApi()

api.upload_folder(
    folder_path="~/.cache/huggingface/lerobot/priya/sim-omx-pick-place",
    repo_id="Pidiya/sim-omx-pick-place",
    repo_type="dataset"
)

print("Upload complete")
# Out:
# Processing Files (6 / 6): 100%|██████████|  327MB /  327MB, 36.3kB/s
# New Data Upload: 100%|██████████|  327MB /  327MB, 36.3kB/s
# Processing Files (0 / 1):   3%|▎         | 8.97MB /  327MB,  0.00B/s
# New Data Upload:   7%|▋         | 8.97MB /  134MB,  0.00B/s
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/smolvla/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~/smolvla/lib/python3.10/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# ...

# %%
from huggingface_hub import HfApi

hub_api = HfApi()
hub_api.create_tag("Pidiya/frankapickplace_200episodes", tag="v3.0", repo_type="dataset")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/smolvla/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~/smolvla/lib/python3.10/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://huggingface.co/api/datasets/Pidiya/frankapickplace_200episodes/tag/main'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# ...
